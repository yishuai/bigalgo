# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

iris_data = pd.read_csv("Iris.csv", na_values=['NA'])
iris_data.head(5).append(iris_data.tail(5))
iris_data.describe()

sns.pairplot(iris_data.dropna(), hue='Species')

# %%
iris_data.loc[(iris_data['Species']=='Iris-setosa')&(iris_data['SepalWidthCm']<2.5)]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 41  42            4.5           2.3            1.3           0.3  Iris-setosa

# %%
iris_data.loc[iris_data['Species']=='Iris-setosa','SepalWidthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
iris_data = iris_data.loc[(iris_data['Species']!='Iris-setosa')|(iris_data['SepalWidthCm']>=2.5)]
iris_data.loc[iris_data['Species']=='Iris-setosa','SepalWidthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
iris_data.loc[(iris_data['PetalWidthCm'].isnull())|(iris_data['PetalLengthCm'].isnull())|(iris_data['SepalWidthCm'].isnull())|(iris_data['SepalLengthCm'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %%
iris_data.to_csv('Iris-data-clean.csv',index=False)
iris_data_clean = pd.read_csv('Iris-data-clean.csv')
sns.pairplot(iris_data_clean, hue='Species')

# %%
a = 1
print("a={}".format(a))
# Out:
# a=1

# %%
a = "x"
b = "y"
c = a + b
print(c)
# Out:
# xy

# %%
a = "bang!"
print(a*3)
# Out:
# bang!bang!bang!

# %%
a = "My name is Peter"
print(a[0:3])
# Out:
# My

# %%
jj = []
jj.append(1)
jj.append('nice hat')
jj
# Out:
# [1, 'nice hat']

# %%
jj = [1, 'nice hat']

# %%
jj = {}
jj['dog'] = 'dalmatian'
jj[1] = 42
jj
# Out:
# {'dog': 'dalmatian', 1: 42}

# %%
a = [1, 2, 3, 4, ]
sA = set(a)
sA
# Out:
# {1, 2, 3, 4}

# %%
sB = set([4, 5, 6, 7])
sA-sB
# Out:
# {1, 2, 3}

# %%
sA | sB
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
sA & sB
# Out:
# {4}

# %%
x = 1
if x < 3: print("it is less than tree man.")
# Out:
# it is less than tree man.

# %%
x = 4
if x < 3: x+=1
elif x == 3: x+=0
else: x = 0
print(x)
# Out:
# 0

# %%
a = {'dog': 'dalmatian', 'cat': 'kitty'}
for item in a:
    print(item, a[item])
# Out:
# dog dalmatian
# cat kitty

# %%
for c in "PYTHON":
    if c == "T" :
        break
    print(c, end="")
# Out:
# PY

# %%
a = 3
while a > 0 :
    a = a-1
    print(a)
# Out:
# 2
# 1
# 0

# %%
a = "tongxi1806"
print("hello, " + a )
# Out:
# hello, tongxi1806

# %%
for i in range(10):
    print(str(i) + "," + a)
# Out:
# 0,tongxi1806
# 1,tongxi1806
# 2,tongxi1806
# 3,tongxi1806
# 4,tongxi1806
# 5,tongxi1806
# 6,tongxi1806
# 7,tongxi1806
# 8,tongxi1806
# 9,tongxi1806
